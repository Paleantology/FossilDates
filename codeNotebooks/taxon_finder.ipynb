# %%
import pandas as pd
from nexusformat.nexus import *
import dendropy
import os
import sys

# %%
r = pd.read_csv("../Data/random_taxa_temp.tsv", sep="\t")
m = pd.read_csv("../Data/Mol/mol_df.tsv", sep="\t")
b = dendropy.StandardCharacterMatrix.get_from_path("../Data/Morph/BardenClean.nex", schema="nexus", preserve_underscores=True)
#b = b.taxon_namespace

# %%
b = dendropy.StandardCharacterMatrix.poll_taxa(b, taxa=None)
b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-4a3c187e648a> in <module>()
# ----> 1 b = dendropy.StandardCharacterMatrix.poll_taxa(b, taxa=None)
#       2 str.b
#
# ~/anaconda3/lib/python3.6/site-packages/dendropy/datamodel/charmatrixmodel.py in poll_taxa(self, taxa)
#     927         if taxa is None:
#     928             taxa = set()
# --> 929         for taxon in self._taxon_sequence_map:
#     930             taxa.add(taxon)
#     931         return taxa
#
# AttributeError: 'set' object has no attribute '_taxon_sequence_map'

# %%
help(dendropy.StandardCharacterMatrix.__str__)
# Out:
# Help on wrapper_descriptor:
#
# __str__(self, /)
#     Return str(self).

# %%
#rm = m[m.taxon.isin(r.taxon.values)]
rm = r[r.taxon.isin(m.taxon)]
rm
# Out:
#                               taxon  age
# 0    Mycetophylax_conformis_GenBank  0.0
# 1           Bothriomyrmex_saundersi  0.0
# 2              Pachycondyla_sp_Mal3  0.0
# 3                Nylanderia_parvula  0.0
# 4               Sphinctomyrmex_CM01  0.0
# 5              Pachycondyla_sp_CAR1  0.0
# 6            Vombisidris_bilongrudi  0.0
# 7               Nylanderia_sp_MAD01  0.0
# 8                     Stigmacros_sp  0.0
# 9              Camponotus_maritimus  0.0
# 10             Phalacromyrmex_fugax  0.0
# 11         Typhlomyrmex_rogenhoferi  0.0
# 12               Dorymyrmex_bicolor  0.0
# 13                  Cerapachys_KH02  0.0
# 14                Simopelta_sp_Ecu1  0.0
# 15                     Aenictus_sp1  0.0
# 16              Euprenolepis_wittei  0.0
# 17                  Brachymyrmex_sp  0.0
# 18         Strumigenys_exiguaevitae  0.0
# 19               Cephalotes_texanus  0.0
# 20            Dacetinops_ignotus_cf  0.0
# 21        Tetramorium_validiusculum  0.0
# ...

# %%
bm = b[b.isin(m.taxon)]
bm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-23f30542c0f9> in <module>()
# ----> 1 bm = b[b.isin(m.taxon)]
#       2 bm
#
# AttributeError: 'set' object has no attribute 'isin'

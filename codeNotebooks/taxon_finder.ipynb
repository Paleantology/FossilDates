# %%
#create list of taxon from r & b that is NOT in m
#r=708
#m=655
#b=35
import pandas as pd

# %%
r = pd.read_csv("../Data/random_taxa_temp.tsv", sep="\t")
m = pd.read_csv("../Data/Mol/mol_df.tsv", sep="\t")
b = pd.read_csv("../Data/Morph/Barden.csv")

# %%
#remove age column in r
r = r.drop('age', axis=1)
r
# Out:
#                               taxon
# 0    Mycetophylax_conformis_GenBank
# 1           Bothriomyrmex_saundersi
# 2              Pachycondyla_sp_Mal3
# 3                Nylanderia_parvula
# 4               Sphinctomyrmex_CM01
# 5              Pachycondyla_sp_CAR1
# 6            Vombisidris_bilongrudi
# 7               Nylanderia_sp_MAD01
# 8                     Stigmacros_sp
# 9              Camponotus_maritimus
# 10             Phalacromyrmex_fugax
# 11         Typhlomyrmex_rogenhoferi
# 12               Dorymyrmex_bicolor
# 13                  Cerapachys_KH02
# 14                Simopelta_sp_Ecu1
# 15                     Aenictus_sp1
# 16              Euprenolepis_wittei
# 17                  Brachymyrmex_sp
# 18         Strumigenys_exiguaevitae
# 19               Cephalotes_texanus
# 20            Dacetinops_ignotus_cf
# 21        Tetramorium_validiusculum
# 22           Pachycondyla_sp_JTL011
# 23            Camponotus_conithorax
# 24                  Huberia_brounii
# ...

# %%
#remove age column in m 
m = m.drop('age', axis=1)
m
# Out:
#                               taxon
# 0    Mycetophylax_conformis_GenBank
# 1           Bothriomyrmex_saundersi
# 2              Pachycondyla_sp_Mal3
# 3                Nylanderia_parvula
# 4               Sphinctomyrmex_CM01
# 5              Pachycondyla_sp_CAR1
# 6            Vombisidris_bilongrudi
# 7               Nylanderia_sp_MAD01
# 8                     Stigmacros_sp
# 9              Camponotus_maritimus
# 10             Phalacromyrmex_fugax
# 11         Typhlomyrmex_rogenhoferi
# 12               Dorymyrmex_bicolor
# 13                  Cerapachys_KH02
# 14                Simopelta_sp_Ecu1
# 15                     Aenictus_sp1
# 16              Euprenolepis_wittei
# 17                  Brachymyrmex_sp
# 18         Strumigenys_exiguaevitae
# 19               Cephalotes_texanus
# 20            Dacetinops_ignotus_cf
# 21        Tetramorium_validiusculum
# 22           Pachycondyla_sp_JTL011
# 23            Camponotus_conithorax
# 24                  Huberia_brounii
# ...

# %%
#Merge method 	SQL Join Name 	Description
#left 	LEFT OUTER JOIN 	Use keys from left frame only
#right 	RIGHT OUTER JOIN 	Use keys from right frame only
#outer 	FULL OUTER JOIN 	Use union of keys from both frames
#inner 	INNER JOIN 	Use intersection of keys from both frames

# %%
#670 of 708 in m
merged1 = pd.merge(r, m, on=['taxon'], how='inner')
merged1.to_csv('../Data/random_in_mol.tsv', sep='\t')

# %%
#12 of 35 in m
merged2 = pd.merge(b, m, on=['taxon'], how='inner')
merged2.to_csv('../Data/barden_in_mol.tsv', sep='\t')

# %%
def pruner(morph1, morph2, mol, outmorph1, outmorph2):
    r = pd.read_csv(morph1, sep="\t")
    b = pd.read_csv(morph2, sep="\t")
    m = pd.read_csv(mol)
    merged1 = pd.merge(r, m, on=['taxon'], how='inner')
    merged1.to_csv('../Data/random_in_mol.tsv', sep='\t')
    merged2 = pd.merge(b, m, on=['taxon'], how='inner')
    merged2.to_csv('../Data/barden_in_mol.tsv', sep='\t')

# %%
pruner('../Data/random_taxa_temp.tsv', '../Data/Morph/Barden.csv', '../Data/Mol/mol_df.tsv', "../Data/aaa.tsv", "../Data/aaaa")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-e099a5c91149> in <module>()
# ----> 1 pruner('../Data/random_taxa_temp.tsv', '../Data/Morph/Barden.csv', '../Data/Mol/mol_df.tsv', "../Data/aaa.tsv", "../Data/aaaa")
#
# <ipython-input-103-3430b221a71d> in pruner(morph1, morph2, mol, outmorph1, outmorph2)
#       3     b = pd.read_csv(morph2, sep="\t")
#       4     m = pd.read_csv(mol)
# ----> 5     merged1 = pd.merge(r, m, on=['taxon'], how='inner')
#       6     merged1.to_csv('../Data/random_in_mol.tsv', sep='\t')
#       7     merged2 = pd.merge(b, m, on=['taxon'], how='inner')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      58                          right_index=right_index, sort=sort, suffixes=suffixes,
# ...
